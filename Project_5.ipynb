# %% [markdown]
# Setup

# %%
import nltk 
import pandas as pd
from nltk.tokenize import RegexpTokenizer
df = pd.read_csv("Project5_data.csv")

"""optional addition for testing so that the code doesnt take 20 minutes to run

df = df.head(10) #number of rows you want to use

there are over 160000 rows so"""

df = df.iloc[:,0]
word_count = []
char_count = []
noun = []
verb = []
adj = []
other = []

# %% [markdown]
# The main function

# %%
# loop through each complaint
for item in df:
    word_lst = []
    char_lst = 0
    count = 0
    count_n = 0
    count_v = 0
    count_a = 0
    count_o = 0
    
    #divide into words and remove puntion
    
    tokenizer = RegexpTokenizer(r'\w+')
    item = tokenizer.tokenize(item)
    
    #tag each word with its part of speach
        
    tagged = nltk.pos_tag(item,tagset='universal')
    tagged = [x[1] for x in tagged]
   
    #separate by part of speach

    for y in tagged:

        if (y == 'NOUN'):
            count_n += 1
        elif (y == 'VERB'):
            count_v += 1
        elif (y == 'ADJ'):
            count_a += 1
        else:
            count_o += 1
            
     #add to the list to be fed into the dataframe       
            
    noun.append(str(count_n))
    verb.append(str(count_v))
    adj.append(str(count_a))
    other.append(str(count_o))
    
    #find unique words and number of characters
              
    for word in item:
        word = word.lower()
        char_lst += len(word)
        if (word not in word_lst):
            word_lst.append(word)
            count += 1
    word_count.append(count)
    char_count.append(char_lst)

# %% [markdown]
# Set up dataframe

# %%
from IPython.display import display, HTML
df1 = pd.DataFrame({'Unique_Words': word_count})
df1 = df1.assign(Character_Count=pd.Series(char_count))
df1 = df1.assign(Nouns=pd.Series(noun))
df1 = df1.assign(Verbs=pd.Series(verb))
df1 = df1.assign(Adjectives=pd.Series(adj))
df1 = df1.assign(Others=pd.Series(other))
pd.set_option('display.max_columns', None)  
display(df1)
# Out:
#         Unique_Words  Character_Count Nouns Verbs Adjectives Others
# 0                 78              557    41    19          9     49
# 1                230             2705   134   157         30    307
# 2                 72              425    18    26          5     55
# 3                123             1083    76    53         19     85
# 4                139             1138    69    74         10    135
# 5                109              973    59    51          9     89
# 6                 69              466    32    23          4     52
# 7                105              821    60    30         12     90
# 8                 46              269    15    17          0     29
# 9                 77              493    27    29          1     56
# 10                86              778    50    42          3     83
# 11                94              774    45    39         10     71
# 12               106              713    48    30          7     78
# 13                56              313    20    15          7     35
# 14                92              605    42    25          8     53
# 15               110              858    48    46         17     73
# 16                50              306    11    19          3     33
# 17               131             1095    66    56          9    139
# 18                75              624    45    39          1     76
# 19                78              546    43    30          7     54
# 20                71              512    33    26          4     58
# 21               105              892    67    35         16     76
# 22               208             2299   208    95         16    212
# 23               132             1246    83    54          6    124
# 24                98              880    68    35          5     89
# 25                28              140     9     8          2     18
# 26                31              158    29     3          0      5
# 27               101              655    29    37         15     70
# 28               175             1400    78    51         23    138
# 29               100              763    38    45          9    101
# ...              ...              ...   ...   ...        ...    ...
# 166118           136             1141    60    71          8    149
# 166119            66              530    45    26          3     66
# 166120           173             1722   123    71         18    184
# 166121           127              973    72    55          9    115
# 166122            73              574    34    22          5     64
# 166123            11               52     3     3          0      7
# 166124           124             1015    78    48         18     95
# 166125           253             2286   142   123         22    308
# 166126           124             1083    70    44         17    125
# 166127           257             3106   164   152         46    338
# 166128           264             2842   135   160         38    332
# 166129           107              920    68    49          7     95
# 166130            74              497    37    24          8     50
# 166131            43              237    14    10          1     34
# 166132           147             1941   142    72         17    162
# 166133           116              905    52    54         10     99
# 166134            60              431    32    20          3     39
# 166135            15               72     4     4          1      6
# 166136           179             1997   110   109         23    251
# 166137            75              543    29    32          3     73
# 166138            74              472    26    27          4     56
# 166139           149             2759   298    85         15    193
# 166140           109              940    44    63          6    123
# 166141            73              464    29    28          1     55
# 166142           176             1983   111   108         18    236
# 166143           109              820    51    44          8     92
# 166144           144             1231    62    79         14    143
# 166145           172             2027   141    99         18    218
# 166146            71              635    34    38         10     66
# 166147            58              321    16    22          1     35
#
# [166148 rows x 6 columns]
